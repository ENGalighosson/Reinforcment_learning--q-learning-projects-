# %%
# !pip install gym
# Out:
# Collecting gym
#   Using cached gym-0.26.2.tar.gz (721 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.18.0 in c:\users\admin\anaconda3\lib\site-packages (from gym) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\admin\anaconda3\lib\site-packages (from gym) (3.0.0)
# Collecting gym_notices>=0.0.4 (from gym)
#   Using cached gym_notices-0.1.0-py3-none-any.whl.metadata (1.2 kB)
# Using cached gym_notices-0.1.0-py3-none-any.whl (3.3 kB)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml): started
#   Building wheel for gym (pyproject.toml): finished with status 'done'
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827737 sha256=806c9f7f77c23968562a0d81663c4729b94c8c27f41a6de2c88ae5f1e690c281
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\95\51\6c\9bb05ebbe7c5cb8171dfaa3611f32622ca4658d53f31c79077
# Successfully built gym
# Installing collected packages: gym_notices, gym
# Successfully installed gym-0.26.2 gym_notices-0.1.0

# %%
import gym
import numpy as np

env = gym.make("MountainCar-v0")  # training env, no render

LEARNING_RATE = 0.1
DISCOUNT = 0.95
EPISODES = 25000
SHOW_EVERY = 200   # show/print every 200 episodes

DISCRETE_OS_SIZE = [20] * len(env.observation_space.high)

discrete_os_win_size = (
    env.observation_space.high - env.observation_space.low
) / DISCRETE_OS_SIZE

q_table = np.random.uniform(
    low=-2,
    high=0,
    size=(DISCRETE_OS_SIZE + [env.action_space.n])
)

def get_discrete_state(state):
    discrete_state = (state - env.observation_space.low) / discrete_os_win_size
    return tuple(discrete_state.astype(int))


for episode in range(EPISODES):

    if episode % SHOW_EVERY == 0:
        print("Episode:", episode, flush=True)

    state, info = env.reset()
    discrete_state = get_discrete_state(state)

    done = False

    while not done:
        action = np.argmax(q_table[discrete_state])

        new_state, reward, terminated, truncated, info = env.step(action)
        new_discrete_state = get_discrete_state(new_state)

        done = terminated or truncated

        if not done:
            max_future_q = np.max(q_table[new_discrete_state])
            current_q = q_table[discrete_state + (action,)]

            new_q = (1 - LEARNING_RATE) * current_q + LEARNING_RATE * (
                reward + DISCOUNT * max_future_q
            )

            q_table[discrete_state + (action,)] = new_q

        elif new_state[0] >= env.unwrapped.goal_position:
            print("Reached goal at episode:", episode, flush=True)
            q_table[discrete_state + (action,)] = 0

        discrete_state = new_discrete_state

    # show the game every 200 episodes
    if episode % SHOW_EVERY == 0:
        render_env = gym.make("MountainCar-v0", render_mode="human")

        state, info = render_env.reset()
        discrete_state = get_discrete_state(state)

        done = False

        while not done:
            action = np.argmax(q_table[discrete_state])

            new_state, reward, terminated, truncated, info = render_env.step(action)
            new_discrete_state = get_discrete_state(new_state)

            done = terminated or truncated
            discrete_state = new_discrete_state

        render_env.close()

env.close()
# Out:
# Episode: 0
# Episode: 200
# Episode: 400
# Reached goal at episode: 437
# Reached goal at episode: 438
# Reached goal at episode: 439
# Reached goal at episode: 441
# Reached goal at episode: 445
# Reached goal at episode: 446
# Reached goal at episode: 448
# Reached goal at episode: 510
# Reached goal at episode: 543
# Episode: 600
# Reached goal at episode: 651
# Reached goal at episode: 652
# Reached goal at episode: 653
# Reached goal at episode: 656
# Reached goal at episode: 660
# Reached goal at episode: 661
# Reached goal at episode: 666
# Reached goal at episode: 670
# Reached goal at episode: 672
# Reached goal at episode: 673
# Reached goal at episode: 675
# Reached goal at episode: 676
# Reached goal at episode: 678
# Reached goal at episode: 688
# Reached goal at episode: 692
# Reached goal at episode: 793
# Episode: 800
# Reached goal at episode: 834
# Reached goal at episode: 857
# Reached goal at episode: 858
# Reached goal at episode: 860
# Reached goal at episode: 861
# Reached goal at episode: 862
# Reached goal at episode: 863
# Reached goal at episode: 866
# Reached goal at episode: 867
# Reached goal at episode: 869
# Reached goal at episode: 871
# Reached goal at episode: 872
# Reached goal at episode: 875
# Reached goal at episode: 877
# Reached goal at episode: 878
# Reached goal at episode: 879
# Reached goal at episode: 880
# Reached goal at episode: 881
# Reached goal at episode: 922
# Reached goal at episode: 923
# Reached goal at episode: 925
# Reached goal at episode: 926
# Reached goal at episode: 929
# Reached goal at episode: 930
# Reached goal at episode: 931
# Reached goal at episode: 934
# Reached goal at episode: 935
# Reached goal at episode: 943
# Reached goal at episode: 945
# Reached goal at episode: 949
# Reached goal at episode: 993
# Reached goal at episode: 999
# Episode: 1000
# Reached goal at episode: 1017
# Reached goal at episode: 1029
# Reached goal at episode: 1030
# Reached goal at episode: 1034
# Reached goal at episode: 1038
# Reached goal at episode: 1040
# Reached goal at episode: 1041
# Reached goal at episode: 1043
# Reached goal at episode: 1053
# Reached goal at episode: 1054
# Reached goal at episode: 1061
# Reached goal at episode: 1064
# Reached goal at episode: 1067
# Reached goal at episode: 1069
# Reached goal at episode: 1074
# Reached goal at episode: 1076
# Reached goal at episode: 1078
# Reached goal at episode: 1079
# Reached goal at episode: 1080
# Reached goal at episode: 1081
# Reached goal at episode: 1082
# Reached goal at episode: 1083
# Reached goal at episode: 1084
# Reached goal at episode: 1085
# Reached goal at episode: 1086
# Reached goal at episode: 1087
# Reached goal at episode: 1088
# Reached goal at episode: 1090
# Reached goal at episode: 1091
# Reached goal at episode: 1092
# Reached goal at episode: 1093
# Reached goal at episode: 1094
# Reached goal at episode: 1095
# Reached goal at episode: 1097
# Reached goal at episode: 1098
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 42
#      39 action = np.argmax(q_table[discrete_state])
#      41 new_state, reward, terminated, truncated, info = env.step(action)
# ---> 42 new_discrete_state = get_discrete_state(new_state)
#      44 done = terminated or truncated
#      46 if not done:
#
# Cell In[13], line 25, in get_discrete_state(state)
#      23 def get_discrete_state(state):
#      24     discrete_state = (state - env.observation_space.low) / discrete_os_win_size
# ---> 25     return tuple(discrete_state.astype(int))
#
# KeyboardInterrupt:
